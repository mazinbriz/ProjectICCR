# %% [markdown]
# # MGSE ICCR: Data Wrangling (Australian Lexicon)
#
#
# Intro:
# Just grab the terms, wrangle and export as csv for visualisation
#
#
# Date: 30/1/2020
#
# Version: 0.01
#
# Environment: Python 3.7.6 and Jupyter notebook
#
# Libraries used:
#     pandas, re, string, csv

# %%
# Import the libraries needed to read and report on data files
import pandas as pd
import re
import numpy as np
import string

# %%
colNames= ('term', 'descr', 'egs')
df = pd.read_csv("AusTerms.csv",names=colNames,skiprows=1)

# df.dropna(how='all', inplace=True)
df.head(62)
# Out:
#                      term                                              descr  \
# 0     answering questions  The activity of responding to a question or a ...
# 1                     NaN                                                NaN
# 2                     NaN                                                NaN
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
# ..                    ...                                                ...
# 57                    NaN                                                NaN
# 58                    NaN                                                NaN
# 59               defining  The teacher or student gives a clear meaning, ...
# 60  (giving a definition)                                                NaN
# 61                    NaN                                                NaN
#
#                                                   egs
# 0                                            Example:
# 1   The teacher asks: “What’s the area of a triang...
# 2   A student responds: “Eighty square centimetres.”
# 3   Another student responds: “Forty square centim...
# 4                                                 NaN
# ..                                                ...
# 57  Copying solutions from the board into a workbook.
# 58                                                NaN
# 59                                           Example:
# 60  The teacher identifies the characteristics of ...
# 61                                                NaN
#
# [62 rows x 3 columns]

# %%
# the next row of a term can be an alternative term (if next is notna )
dfConcats = df
dfConcats['SameTerm'] =  (dfConcats.term.notna()) &(dfConcats.term.shift(-1).notna())
# show terms with an alternative 
dfConcats[((dfConcats.term.notna()) &(dfConcats.term.shift(-1).notna()))]
# Out:
#                 term                                              descr  \
# 59          defining  The teacher or student gives a clear meaning, ...
# 72   differentiating  Any action in which instruction is modified, a...
# 106         engaging  A student is actively involved with an educati...
# 113       explaining  Make an idea or situation clear to someone by ...
#
#            egs  SameTerm
# 59    Example:      True
# 72   Examples:      True
# 106  Examples:      True
# 113   Example:      True

# %%
# set the Alt description
dfConcats['alt'] = np.nan
dfConcats.loc[dfConcats.SameTerm==True,'alt'] = dfConcats.term.shift(-1)

dfConcats.head(62)
# Out:
#                      term                                              descr  \
# 0     answering questions  The activity of responding to a question or a ...
# 1                     NaN                                                NaN
# 2                     NaN                                                NaN
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
# ..                    ...                                                ...
# 57                    NaN                                                NaN
# 58                    NaN                                                NaN
# 59               defining  The teacher or student gives a clear meaning, ...
# 60  (giving a definition)                                                NaN
# 61                    NaN                                                NaN
#
#                                                   egs  SameTerm  \
# 0                                            Example:     False
# 1   The teacher asks: “What’s the area of a triang...     False
# 2   A student responds: “Eighty square centimetres.”      False
# 3   Another student responds: “Forty square centim...     False
# 4                                                 NaN     False
# ..                                                ...       ...
# 57  Copying solutions from the board into a workbook.     False
# 58                                                NaN     False
# 59                                           Example:      True
# 60  The teacher identifies the characteristics of ...     False
# 61                                                NaN     False
#
#                       alt
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 57                    NaN
# 58                    NaN
# 59  (giving a definition)
# 60                    NaN
# 61                    NaN
#
# [62 rows x 5 columns]

# %%
dfConcats.loc[dfConcats.SameTerm.shift()==True,'term']
# Out:
# 60     (giving a definition)
# 73         (differentiation)
# 107             (engagement)
# 114            (explanation)
# Name: term, dtype: object

# %%
# then null out the ones that aren't actually alt
dfConcats.loc[dfConcats.SameTerm.shift()==True,'term'] =np.nan
dfConcats.head(62)
# Out:
#                    term                                              descr  \
# 0   answering questions  The activity of responding to a question or a ...
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# ..                  ...                                                ...
# 57                  NaN                                                NaN
# 58                  NaN                                                NaN
# 59             defining  The teacher or student gives a clear meaning, ...
# 60                  NaN                                                NaN
# 61                  NaN                                                NaN
#
#                                                   egs  SameTerm  \
# 0                                            Example:     False
# 1   The teacher asks: “What’s the area of a triang...     False
# 2   A student responds: “Eighty square centimetres.”      False
# 3   Another student responds: “Forty square centim...     False
# 4                                                 NaN     False
# ..                                                ...       ...
# 57  Copying solutions from the board into a workbook.     False
# 58                                                NaN     False
# 59                                           Example:      True
# 60  The teacher identifies the characteristics of ...     False
# 61                                                NaN     False
#
#                       alt
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 57                    NaN
# 58                    NaN
# 59  (giving a definition)
# 60                    NaN
# 61                    NaN
#
# [62 rows x 5 columns]

# %%
df = dfConcats
# fill in terms for further grouping
df['term'].fillna(method='ffill',inplace=True)

df['term'] = df['term'].apply(lambda x: x.strip())
df.head()
# Out:
#                   term                                              descr  \
# 0  answering questions  The activity of responding to a question or a ...
# 1  answering questions                                                NaN
# 2  answering questions                                                NaN
# 3  answering questions                                                NaN
# 4  answering questions                                                NaN
#
#                                                  egs  SameTerm  alt
# 0                                           Example:     False  NaN
# 1  The teacher asks: “What’s the area of a triang...     False  NaN
# 2  A student responds: “Eighty square centimetres.”      False  NaN
# 3  Another student responds: “Forty square centim...     False  NaN
# 4                                                NaN     False  NaN

# %%
df[df['term']=="applying"]
# Out:
#         term                                              descr  \
# 5   applying  An activity in which a taught procedure or con...
# 6   applying                                                NaN
# 7   applying                                                NaN
# 8   applying                                                NaN
# 9   applying                                                NaN
# 10  applying                                                NaN
# 11  applying                                                NaN
#
#                                                   egs  SameTerm  alt
# 5                                           Examples:     False  NaN
# 6   Having been taught Pythagoras theorem using tw...     False  NaN
# 7   Having been taught strategies for solving simu...     False  NaN
# 8                                                 NaN     False  NaN
# 9                                        Non-example:     False  NaN
# 10  Solving a pair of simultaneous equations after...     False  NaN
# 11                                                NaN     False  NaN

# %%
# turn nan into spaces
df['descr'] = df['descr'].replace(np.nan,' ',regex=True)
df['egs'] = df['egs'].replace(np.nan,' ',regex=True)
df['alt'] = df['alt'].replace(np.nan,' ',regex=True)
df.head()
# Out:
#                   term                                              descr  \
# 0  answering questions  The activity of responding to a question or a ...
# 1  answering questions
# 2  answering questions
# 3  answering questions
# 4  answering questions
#
#                                                  egs  SameTerm alt
# 0                                           Example:     False
# 1  The teacher asks: “What’s the area of a triang...     False
# 2  A student responds: “Eighty square centimetres.”      False
# 3  Another student responds: “Forty square centim...     False
# 4                                                        False

# %%
df[df['term']=="checking"]
# Out:
#         term                                              descr  \
# 34  checking          The process by which a teacher or student
# 35  checking
# 36  checking  • checks answers, by determining the exactness...
# 37  checking  • checks progress, by determining whether the ...
# 38  checking
# 39  checking
#
#                                                   egs  SameTerm alt
# 34                                          Examples:     False
# 35  The teacher makes notes in her chronicle to in...     False
# 36    The teacher makes a mental note or observation.     False
# 37                                                        False
# 38                                       Non-example:     False
# 39        Students annotate their workbook solutions.     False

# %%
# concatenate examples split across rows
groupDescr = df.groupby('term')['descr'].apply(''.join)
groupDescr
# Out:
# term
# (use of a) hook           The engaging introduction of a topic or sub-to...
# answering questions       The activity of responding to a question or a ...
# applying                  An activity in which a taught procedure or con...
# assessment                An activity undertaken by teacher or students ...
# assigning homework        The teacher assigns tasks to be completed outs...
#                                                 ...
# summative assessment      Information is collected for the purpose of su...
# test/testing              A situation in which individuals are required ...
# wait time                 A deliberate pause before or after a question ...
# whole class discussion    An activity in which the teacher and students ...
# worked example            The teacher (or student) writes out the steps ...
# Name: descr, Length: 61, dtype: object

# %%
groupEgs = df.groupby('term')['egs'].apply(' '.join)
groupEgs
# Out:
# term
# (use of a) hook           Example: The teacher introduces polyhedra with...
# answering questions       Example: The teacher asks: “What’s the area of...
# applying                  Examples: Having been taught Pythagoras theore...
# assessment                Examples: The teacher administers a test. The ...
# assigning homework        Example: The teacher writes the homework on th...
#                                                 ...
# summative assessment      Examples: Students complete a test that measur...
# test/testing              Examples: Students complete a complex problem ...
# wait time                 Example: The teacher says: “What is the area o...
# whole class discussion    Example: The teacher invites students to share...
# worked example            Example: The teacher writes out the solution t...
# Name: egs, Length: 61, dtype: object

# %%
dfSumm = df[['term','alt']].drop_duplicates()
dfSumm.head(20)
# Out:
#                      term                    alt
# 0     answering questions
# 5                applying
# 12             assessment
# 20     assigning homework
# 26             board work
# 34               checking
# 40             clarifying
# 46        collecting work
# 52             correcting
# 59               defining  (giving a definition)
# 60               defining
# 65          demonstrating
# 72        differentiating      (differentiation)
# 73        differentiating
# 79           disciplining
# 85            elaborating
# 91   elicit understanding
# 99            encouraging
# 106              engaging           (engagement)
# 107              engaging

# %%
df = pd.merge(dfSumm,groupDescr,on='term')
df = pd.merge(df,groupEgs,on='term')
df
# Out:
#                       term alt  \
# 0      answering questions
# 1                 applying
# 2               assessment
# 3       assigning homework
# 4               board work
# ..                     ...  ..
# 60    summative assessment
# 61            test/testing
# 62               wait time
# 63  whole class discussion
# 64          worked example
#
#                                                 descr  \
# 0   The activity of responding to a question or a ...
# 1   An activity in which a taught procedure or con...
# 2   An activity undertaken by teacher or students ...
# 3   The teacher assigns tasks to be completed outs...
# 4   The teacher or students record workings, diagr...
# ..                                                ...
# 60  Information is collected for the purpose of su...
# 61  A situation in which individuals are required ...
# 62  A deliberate pause before or after a question ...
# 63  An activity in which the teacher and students ...
# 64  The teacher (or student) writes out the steps ...
#
#                                                   egs
# 0   Example: The teacher asks: “What’s the area of...
# 1   Examples: Having been taught Pythagoras theore...
# 2   Examples: The teacher administers a test. The ...
# 3   Example: The teacher writes the homework on th...
# 4   Examples: A student solves a problem on the bo...
# ..                                                ...
# 60  Examples: Students complete a test that measur...
# 61  Examples: Students complete a complex problem ...
# 62  Example: The teacher says: “What is the area o...
# 63  Example: The teacher invites students to share...
# 64  Example: The teacher writes out the solution t...
#
# [65 rows x 4 columns]

# %%
# Grab the author categories
colNames = ('catdescr','term')
dfCat = pd.read_csv("AusCategories.csv",names=colNames,skiprows=1)
dfCat = dfCat.dropna().reset_index(drop=True)
dfCat
# Out:
#                catdescr                                               term
# 0            Assessment  assessment, correcting, elicit understanding, ...
# 1  Classroom Management  disciplining, encouraging, giving praise, moni...
# 2   Learning Strategies  answering questions, applying, board work, che...
# 3   Teaching Strategies  answering questions, applying, assigning homew...

# %%
# keep the index as the id for the category
dfCat['cat'] = ['cat'+str(int(x)) for x in dfCat.index]
dfCat
# Out:
#                catdescr                                               term  \
# 0            Assessment  assessment, correcting, elicit understanding, ...
# 1  Classroom Management  disciplining, encouraging, giving praise, moni...
# 2   Learning Strategies  answering questions, applying, board work, che...
# 3   Teaching Strategies  answering questions, applying, assigning homew...
#
#     cat
# 0  cat0
# 1  cat1
# 2  cat2
# 3  cat3

# %%
# explode terms into one row for each term for each category
dfCat.term = [x.split(',') for x in dfCat.term]
dfCat = dfCat.explode('term').reset_index(drop=True)
dfCat.term = [x.strip() for x in dfCat.term]
dfCat
# Out:
#                catdescr                       term   cat
# 0            Assessment                 assessment  cat0
# 1            Assessment                 correcting  cat0
# 2            Assessment       elicit understanding  cat0
# 3            Assessment                   feedback  cat0
# 4            Assessment       formative assessment  cat0
# ..                  ...                        ...   ...
# 88  Teaching Strategies  student (individual) work  cat3
# 89  Teaching Strategies                summarising  cat3
# 90  Teaching Strategies                  wait time  cat3
# 91  Teaching Strategies     whole class discussion  cat3
# 92  Teaching Strategies             worked example  cat3
#
# [93 rows x 3 columns]

# %%
colNames= ['term', 'descr', 'cat']
df = pd.merge(df,dfCat,on='term')
#df = df[colNames]
df.head(20)
# Out:
#                    term                    alt  \
# 0   answering questions
# 1   answering questions
# 2              applying
# 3              applying
# 4            assessment
# 5    assigning homework
# 6            board work
# 7            board work
# 8              checking
# 9              checking
# 10           clarifying
# 11           clarifying
# 12           correcting
# 13           correcting
# 14             defining  (giving a definition)
# 15             defining  (giving a definition)
# 16             defining
# 17             defining
# 18        demonstrating
# 19      differentiating      (differentiation)
#
#                                                 descr  \
# 0   The activity of responding to a question or a ...
# 1   The activity of responding to a question or a ...
# 2   An activity in which a taught procedure or con...
# 3   An activity in which a taught procedure or con...
# 4   An activity undertaken by teacher or students ...
# 5   The teacher assigns tasks to be completed outs...
# 6   The teacher or students record workings, diagr...
# 7   The teacher or students record workings, diagr...
# 8   The process by which a teacher or student • ch...
# 9   The process by which a teacher or student • ch...
# 10  The process by which a teacher or student make...
# 11  The process by which a teacher or student make...
# 12  The process by which a teacher or student iden...
# 13  The process by which a teacher or student iden...
# 14  The teacher or student gives a clear meaning, ...
# 15  The teacher or student gives a clear meaning, ...
# 16  The teacher or student gives a clear meaning, ...
# 17  The teacher or student gives a clear meaning, ...
# 18  An activity undertaken by the teacher or stude...
# 19  Any action in which instruction is modified, a...
#
#                                                   egs             catdescr  \
# 0   Example: The teacher asks: “What’s the area of...  Learning Strategies
# 1   Example: The teacher asks: “What’s the area of...  Teaching Strategies
# 2   Examples: Having been taught Pythagoras theore...  Learning Strategies
# 3   Examples: Having been taught Pythagoras theore...  Teaching Strategies
# 4   Examples: The teacher administers a test. The ...           Assessment
# 5   Example: The teacher writes the homework on th...  Teaching Strategies
# 6   Examples: A student solves a problem on the bo...  Learning Strategies
# 7   Examples: A student solves a problem on the bo...  Teaching Strategies
# 8   Examples: The teacher makes notes in her chron...  Learning Strategies
# 9   Examples: The teacher makes notes in her chron...  Teaching Strategies
# 10  Example: The teacher comments on each written ...  Learning Strategies
# 11  Example: The teacher comments on each written ...  Teaching Strategies
# 12  Examples: Students annotate their solutions wi...           Assessment
# 13  Examples: Students annotate their solutions wi...  Learning Strategies
# 14  Example: The teacher identifies the characteri...  Learning Strategies
# 15  Example: The teacher identifies the characteri...  Teaching Strategies
# 16  Example: The teacher identifies the characteri...  Learning Strategies
# 17  Example: The teacher identifies the characteri...  Teaching Strategies
# 18  Examples: The teacher draws a diagram of a cir...  Teaching Strategies
# 19  Examples: The teacher groups students for inst...  Teaching Strategies
#
#      cat
# 0   cat2
# 1   cat3
# 2   cat2
# 3   cat3
# 4   cat0
# 5   cat3
# 6   cat2
# 7   cat3
# 8   cat2
# 9   cat3
# 10  cat2
# 11  cat3
# 12  cat0
# 13  cat2
# 14  cat2
# 15  cat3
# 16  cat2
# 17  cat3
# 18  cat3
# 19  cat3

# %%
df['egs'][10]
# Out:
# 'Example: The teacher comments on each written line of a worked solution on the board.   Non-example: Repeating a statement made previously.  '

# %%
colnames = df.columns
colnames
# Out:
# Index(['term', 'alt', 'descr', 'egs', 'catdescr', 'cat'], dtype='object')

# %%
# create dodge columns for visualisation code
df['amount'] = np.random.randint(8,12,len(df.index))
df['id'] = df.index
# reorder columsn for visualisation code
colnames = ['id','term', 'catdescr','alt', 'descr', 'egs',  'cat','amount']
df = df[colnames]
df.head()
# Out:
#    id                 term             catdescr alt  \
# 0   0  answering questions  Learning Strategies
# 1   1  answering questions  Teaching Strategies
# 2   2             applying  Learning Strategies
# 3   3             applying  Teaching Strategies
# 4   4           assessment           Assessment
#
#                                                descr  \
# 0  The activity of responding to a question or a ...
# 1  The activity of responding to a question or a ...
# 2  An activity in which a taught procedure or con...
# 3  An activity in which a taught procedure or con...
# 4  An activity undertaken by teacher or students ...
#
#                                                  egs   cat  amount
# 0  Example: The teacher asks: “What’s the area of...  cat2      11
# 1  Example: The teacher asks: “What’s the area of...  cat3       8
# 2  Examples: Having been taught Pythagoras theore...  cat2      10
# 3  Examples: Having been taught Pythagoras theore...  cat3      11
# 4  Examples: The teacher administers a test. The ...  cat0       9

# %%
df.iloc[20:30,:]
# Out:
#     id                  term              catdescr           alt  \
# 20  20       differentiating   Teaching Strategies
# 21  21          disciplining  Classroom Management
# 22  22           elaborating   Teaching Strategies
# 23  23  elicit understanding            Assessment
# 24  24  elicit understanding   Teaching Strategies
# 25  25           encouraging  Classroom Management
# 26  26           encouraging   Teaching Strategies
# 27  27              engaging   Learning Strategies  (engagement)
# 28  28              engaging   Teaching Strategies  (engagement)
# 29  29              engaging   Learning Strategies
#
#                                                 descr  \
# 20  Any action in which instruction is modified, a...
# 21  The teacher identifies undesirable behaviour t...
# 22  A teacher or student provides additional infor...
# 23  An activity undertaken by the teacher or stude...
# 24  An activity undertaken by the teacher or stude...
# 25  An action undertaken by the teacher for the pu...
# 26  An action undertaken by the teacher for the pu...
# 27  A student is actively involved with an educati...
# 28  A student is actively involved with an educati...
# 29  A student is actively involved with an educati...
#
#                                                   egs   cat  amount
# 20  Examples: The teacher groups students for inst...  cat3      10
# 21  Example: A teacher stops her activity and asks...  cat1      10
# 22  Example: The teacher shades the fraction one-h...  cat3      10
# 23  Examples: The teacher asks a student to demons...  cat0      10
# 24  Examples: The teacher asks a student to demons...  cat3       8
# 25  Examples: A teacher comments: "Keep trying." "...  cat1      10
# 26  Examples: A teacher comments: "Keep trying." "...  cat3      11
# 27  Examples: A student keeps working on solving a...  cat2      11
# 28  Examples: A student keeps working on solving a...  cat3       8
# 29  Examples: A student keeps working on solving a...  cat2       8

# %%
df.to_csv('AusData.csv',index=False)

# %%
# dodge data hack for bubble chart viz
# df[['Term','Views']].to_csv('data_fdi.csv',index=False)

# %%
df[['catdescr','cat']].drop_duplicates()
# Out:
#                 catdescr   cat
# 0    Learning Strategies  cat2
# 1    Teaching Strategies  cat3
# 4             Assessment  cat0
# 21  Classroom Management  cat1

# %%
df[['catdescr','cat']].drop_duplicates().to_csv('AusCatData.csv',index=False)
